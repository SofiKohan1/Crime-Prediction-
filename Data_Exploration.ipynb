# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#loading data file
df_sf = pd.read_csv('Datasets\Police_Department_Incidents.csv')

# %%
df_sf #a review of the dataset (top 5 and last 5 instances)
# Out:
#         IncidntNum        Category  \
# 0        120058272     WEAPON LAWS
# 1        120058272     WEAPON LAWS
# 2        141059263        WARRANTS
# 3        160013662    NON-CRIMINAL
# 4        160002740    NON-CRIMINAL
# ...            ...             ...
# 150495   161061000         ASSAULT
# 150496   176000742    NON-CRIMINAL
# 150497   176000758   LARCENY/THEFT
# 150498   176000764   LARCENY/THEFT
# 150499   179002868  OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 3                                           LOST PROPERTY   Tuesday
# 4                                           LOST PROPERTY    Friday
# ...                                                   ...       ...
# ...

# %%
df_sf.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150500 entries, 0 to 150499
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   IncidntNum  150500 non-null  int64
#  1   Category    150500 non-null  object
#  2   Descript    150500 non-null  object
#  3   DayOfWeek   150500 non-null  object
#  4   Date        150500 non-null  object
#  5   Time        150500 non-null  object
#  6   PdDistrict  150499 non-null  object
#  7   Resolution  150500 non-null  object
#  8   Address     150500 non-null  object
#  9   X           150500 non-null  float64
#  10  Y           150500 non-null  float64
#  11  Location    150500 non-null  object
#  12  PdId        150500 non-null  float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 97.9 MB

# %%
'''
where X and Y are coordenates 
features:
    Indicent Number
    Category
    Description
    DayOfWeek
    Date
    Time
    PdDistrict
    Resolution
    Address
    X 
    Y
    Location 
    PdId
    
3 data types: 
    float (2): X & Y
    int(2): PdId and IncidentNum
    objects(9)
'''
# Out:
# '\nwhere X and Y are coordenates \nfeatures:\n    Indicent Number\n    Category\n    Description\n    DayOfWeek\n    Date\n    Time\n    PdDistrict\n    Resolution\n    Address\n    X \n    Y\n    Location \n    PdId\n    \n3 data types: \n    float (2): X & Y\n    int(2): PdId and IncidentNum\n    objects(9)\n'

# %%
df_sf.size #total number of elements in the object
# Out:
# 1956500

# %%
print("Shape:",df_sf.shape) # 13 dimension dataset ith 150500 instances in it
# Out:
# Shape: (150500, 13)

# %%
df_sf['Date'].describe()
# Out:
# count            150500
# unique              366
# top       1/1/2016 0:00
# freq                558
# Name: Date, dtype: object

# %%
df_sf.isnull().sum() #what am I going to do with this missing value? Impute? Drop? How do I impute a string object? actually drop it
# Out:
# IncidntNum    0
# Category      0
# Descript      0
# DayOfWeek     0
# Date          0
# Time          0
# PdDistrict    1
# Resolution    0
# Address       0
# X             0
# Y             0
# Location      0
# PdId          0
# dtype: int64

# %%
df_sf.select_dtypes(include=['object'])
# Out:
#               Category                                           Descript  \
# 0          WEAPON LAWS                          POSS OF PROHIBITED WEAPON
# 1          WEAPON LAWS     FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2             WARRANTS                                     WARRANT ARREST
# 3         NON-CRIMINAL                                      LOST PROPERTY
# 4         NON-CRIMINAL                                      LOST PROPERTY
# ...                ...                                                ...
# 150495         ASSAULT                                            BATTERY
# 150496    NON-CRIMINAL                                      LOST PROPERTY
# 150497   LARCENY/THEFT                            PETTY THEFT OF PROPERTY
# 150498   LARCENY/THEFT                            GRAND THEFT OF PROPERTY
# 150499  OTHER OFFENSES  FRAUDULENT GAME OR TRICK, OBTAINING MONEY OR P...
#
#        DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# ...

# %%
#no signs of duplicated values
df_sf.duplicated().value_counts()
# Out:
# False    150500
# dtype: int64

# %%
'''
SOUTHERN      28445    Class=7    (18.769%)
NORTHERN      20100    Class=4    (13.378%)
MISSION       19503    Class=3    (12.980%)
CENTRAL       17666    Class=1    (11.758%)
BAYVIEW       14303    Class=0    (9.519%)
INGLESIDE     11594    Class=2    (7.716%)
TARAVAL       11325    Class=8    (7.537%)
TENDERLOIN     9942    Class=9    (6.617%)
RICHMOND       8922    Class=6    (5.935%)
PARK           8699    Class=5    (5.790%)
 
'''

# %%
#values per district
df_sf["PdDistrict"].value_counts()
# Out:
# SOUTHERN      28445
# NORTHERN      20100
# MISSION       19503
# CENTRAL       17666
# BAYVIEW       14303
# INGLESIDE     11594
# TARAVAL       11325
# TENDERLOIN     9942
# RICHMOND       8922
# PARK           8699
# Name: PdDistrict, dtype: int64

# %%
#values per resolution
df_sf["Resolution"].value_counts()
# Out:
# NONE                                      107780
# ARREST, BOOKED                             39416
# UNFOUNDED                                   1608
# JUVENILE BOOKED                             1056
# EXCEPTIONAL CLEARANCE                        371
# ARREST, CITED                                144
# CLEARED-CONTACT JUVENILE FOR MORE INFO        58
# NOT PROSECUTED                                22
# LOCATED                                       20
# PSYCHOPATHIC CASE                             17
# JUVENILE CITED                                 3
# COMPLAINANT REFUSES TO PROSECUTE               2
# JUVENILE DIVERTED                              2
# PROSECUTED BY OUTSIDE AGENCY                   1
# Name: Resolution, dtype: int64

# %%
#checking latitudes and longiudes
df_sf[['X','Y']].describe()
# Out:
#                    X              Y
# count  150500.000000  150500.000000
# mean     -122.423599      37.768921
# std         0.026210       0.023637
# min      -122.513642      37.707922
# 25%      -122.434036      37.756486
# 50%      -122.416903      37.775421
# 75%      -122.406605      37.785063
# max      -122.365565      37.819975

# %%
pd.crosstab(df_sf['Category'], df_sf['Resolution'])
# Out:
# Resolution                   ARREST, BOOKED  ARREST, CITED  \
# Category
# ARSON                                    73              1
# ASSAULT                                5416              7
# BAD CHECKS                                2              0
# BRIBERY                                  23              0
# BURGLARY                               1018              0
# DISORDERLY CONDUCT                      285              0
# DRIVING UNDER THE INFLUENCE             358              0
# DRUG/NARCOTIC                          3806              7
# DRUNKENNESS                             351              0
# EMBEZZLEMENT                             37              0
# EXTORTION                                 0              0
# FAMILY OFFENSES                          22              0
# FORGERY/COUNTERFEITING                  164              1
# FRAUD                                   413              0
# GAMBLING                                 12              0
# ...

# %%
#the most common resolution is none...  does this have an impact on what i want to do?
df_sf['Resolution'].value_counts()
# Out:
# NONE                                      107780
# ARREST, BOOKED                             39416
# UNFOUNDED                                   1608
# JUVENILE BOOKED                             1056
# EXCEPTIONAL CLEARANCE                        371
# ARREST, CITED                                144
# CLEARED-CONTACT JUVENILE FOR MORE INFO        58
# NOT PROSECUTED                                22
# LOCATED                                       20
# PSYCHOPATHIC CASE                             17
# JUVENILE CITED                                 3
# JUVENILE DIVERTED                              2
# COMPLAINANT REFUSES TO PROSECUTE               2
# PROSECUTED BY OUTSIDE AGENCY                   1
# Name: Resolution, dtype: int64
